# %%
# %run Covid.ipynb  
# %run Stop_Search.ipynb

from tkinter import *
# Out:
# ['avon-and-somerset', 'bedfordshire', 'cambridgeshire', 'cheshire', 'city-of-london', 'cleveland', 'cumbria', 'derbyshire', 'devon-and-cornwall', 'dorset', 'durham', 'dyfed-powys', 'essex', 'gloucestershire', 'greater-manchester', 'gwent', 'hampshire', 'hertfordshire', 'humberside', 'kent', 'lancashire', 'leicestershire', 'lincolnshire', 'merseyside', 'metropolitan', 'norfolk', 'north-wales', 'north-yorkshire', 'northamptonshire', 'northumbria', 'nottinghamshire', 'northern-ireland', 'south-wales', 'south-yorkshire', 'staffordshire', 'suffolk', 'surrey', 'sussex', 'thames-valley', 'warwickshire', 'west-mercia', 'west-midlands', 'west-yorkshire', 'wiltshire']

# %%
# setting the Width and height of the frame

WIDTH = 900
HEIGHT = 800





# defining a funtion to show the frame to show frame basically
def show_frame(framename):
    framename.tkraise()
    
# root configuration and set up
root = Tk()
root.title("ICA ON COVID & STOP and SEARCH")
root.geometry('960x840')
root.rowconfigure(0, weight=1)
root.columnconfigure(0, weight=1)

Home_page = Frame(root, width=WIDTH, height=HEIGHT, bg='green')
covid19_frame = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
SandS = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
linechart = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
piechart = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
monthplot = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
barchart = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
Area_type = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
Area_code = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
Area_name = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
Months = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
Area_type1 = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
Area_code1 = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
Area_name1 = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
Months1 = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
area_type_pie = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
area_name_pie = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
area_code_pie = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
month_pie = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
area_type_bar = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
area_name_bar = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
area_code_bar = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
month_bar = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
boxplot = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
SandS_hist = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
arrests = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
m_SandS = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
gen_hist = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')
eth_hist = Frame(root, width=WIDTH, height=HEIGHT, bg='blue')

for frame in (Home_page, covid19_frame, SandS, linechart, piechart, monthplot, barchart, Area_type, Area_code, Area_name,
              Months, Area_type1, Area_code1, Area_name1, Months1, area_type_pie, area_name_pie, area_code_pie, month_pie, 
              area_type_bar, area_name_bar, area_code_bar, month_bar, boxplot, SandS_hist, arrests, m_SandS, gen_hist, eth_hist):
    frame.grid(row=0, column=0, sticky='nsew')
    if frame != Home_page:
        A1 = Button(frame, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
        A1.pack(fill='both', expand="True")
        A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')

        
# For the Home Page        

Home_label = Label(Home_page, text="Hello, How may i help you today?")
Home_label.pack(fill='both', expand='True')
Home_label.place(relx=0.5, rely=0.1, relwidth=0.75, relheight=0.1, anchor='n')

First_button = Button(Home_page, text="COVID-19 cases in Uk", command=lambda: show_frame(covid19_frame))
First_button.pack(fill='both', expand="True")
First_button.place(relx=0.3, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

second_button = Button(Home_page, text="Stop and Search Data", command=lambda: show_frame(SandS))
second_button.pack(fill='both', expand="True")
second_button.place(relx=0.7, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

##################################################################################################################
# for covid 19

covid19_label = Label(covid19_frame, text="Please select the chart you want to use for visualization?")
covid19_label.pack(fill='both', expand='True')
covid19_label.place(relx=0.5, rely=0.1, relwidth=0.75, relheight=0.1, anchor='n')

covid1_button = Button(covid19_frame, text="Line Graph", command=lambda: show_frame(linechart))
covid1_button.pack(fill='both', expand="True")
covid1_button.place(relx=0.2, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid2_button = Button(covid19_frame, text="Pie Chart", command=lambda: show_frame(piechart))
covid2_button.pack(fill='both', expand="True")
covid2_button.place(relx=0.4, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')
 
covid3_button = Button(covid19_frame, text="Box Plot", command=lambda: show_frame(boxplot))
covid3_button.pack(fill='both', expand="True")
covid3_button.place(relx=0.6, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid4_button = Button(covid19_frame, text="Horizontal barchart", command=lambda: show_frame(barchart))
covid4_button.pack(fill='both', expand="True")
covid4_button.place(relx=0.8, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')


# for linechart

covid19_linechart_label = Label(linechart, text="Select condition for visualization")
covid19_linechart_label.pack(fill='both', expand='True')
covid19_linechart_label.place(relx=0.5, rely=0.1, relwidth=0.75, relheight=0.1, anchor='n')

covid19_linechart_button1 = Button(linechart, text="Area Code", command=lambda: show_frame(Area_code))
covid19_linechart_button1.pack(fill='both', expand="True")
covid19_linechart_button1.place(relx=0.2, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid19_linechart_button2 = Button(linechart, text="Area Name", command=lambda: show_frame(Area_name))
covid19_linechart_button2.pack(fill='both', expand="True")
covid19_linechart_button2.place(relx=0.4, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid19_linechart_button3 = Button(linechart, text="Area Type", command=lambda: show_frame(Area_type))
covid19_linechart_button3.pack(fill='both', expand="True")
covid19_linechart_button3.place(relx=0.6, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid19_linechart_button3 = Button(linechart, text="Month", command=lambda: show_frame(Months))
covid19_linechart_button3.pack(fill='both', expand="True")
covid19_linechart_button3.place(relx=0.8, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')


#==============================================


# for pie chart
covid19_piechart_label = Label(piechart, text="Select condition for visualization")
covid19_piechart_label.pack(fill='both', expand='True')
covid19_piechart_label.place(relx=0.5, rely=0.1, relwidth=0.75, relheight=0.1, anchor='n')

covid19_piechart_button1 = Button(piechart, text="Area Code", command=lambda: show_frame(area_code_pie))
covid19_piechart_button1.pack(fill='both', expand="True")
covid19_piechart_button1.place(relx=0.2, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid19_piechart_button2 = Button(piechart, text="Area Name", command=lambda: show_frame(area_name_pie))
covid19_piechart_button2.pack(fill='both', expand="True")
covid19_piechart_button2.place(relx=0.4, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid19_piechart_button3 = Button(piechart, text="Area Type", command=lambda: show_frame(area_type_pie))
covid19_piechart_button3.pack(fill='both', expand="True")
covid19_piechart_button3.place(relx=0.6, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid19_piechart_button3 = Button(piechart, text="Month", command=lambda: show_frame(month_pie))
covid19_piechart_button3.pack(fill='both', expand="True")
covid19_piechart_button3.place(relx=0.8, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')




# for bar chart
covid19_barchart_label = Label(barchart, text="Select condition for visualization")
covid19_barchart_label.pack(fill='both', expand='True')
covid19_barchart_label.place(relx=0.5, rely=0.1, relwidth=0.75, relheight=0.1, anchor='n')

covid19_barchart_button1 = Button(barchart, text="Area Code", command=lambda: show_frame(area_code_bar))
covid19_barchart_button1.pack(fill='both', expand="True")
covid19_barchart_button1.place(relx=0.2, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid19_barchart_button2 = Button(barchart, text="Area Name", command=lambda: show_frame(area_name_bar))
covid19_barchart_button2.pack(fill='both', expand="True")
covid19_barchart_button2.place(relx=0.4, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid19_barchart_button3 = Button(barchart, text="Area Type", command=lambda: show_frame(area_type_bar))
covid19_barchart_button3.pack(fill='both', expand="True")
covid19_barchart_button3.place(relx=0.6, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

covid19_barchart_button3 = Button(barchart, text="Month", command=lambda: show_frame(month_bar))
covid19_barchart_button3.pack(fill='both', expand="True")
covid19_barchart_button3.place(relx=0.8, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')


# defining functions for line chart

def type_linechart(x):
    line_plot(df_covid_data, 'Area_Type', str(x))
    


t_area = StringVar(Area_type)
t_area.set("Select")
D0 = OptionMenu(Area_type, t_area, *unique_Areatype, command=type_linechart)
D0.config(width=20, height=4)
D0.pack(padx=50, pady=50)




def name_linechart(x):
    value = str((listbox_Area_name_linechart.get(listbox_Area_name_linechart.curselection())))
    if value != 0:
        line_plot(df_covid_data, 'Area_Name', value)
        


listbox_Area_name_linechart = Listbox(Area_name)
listbox_Area_name_linechart.pack(side=LEFT, fill=BOTH, expand=True)
scrollbar_Area_name = Scrollbar(Area_name)

scrollbar_Area_name.pack(side=RIGHT, fill=BOTH)

for i in unique_AreaName:
    listbox_Area_name_linechart.insert(END, i)

listbox_Area_name_linechart.config(yscrollcommand=scrollbar_Area_name.set)
scrollbar_Area_name.config(command=listbox_Area_name_linechart.yview)

listbox_Area_name_linechart.bind('<<ListboxSelect>>', name_linechart)

A1 = Button(Area_name, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')




def code_linechart(x):
    value = str((listbox_Area_code_linechart.get(listbox_Area_code_linechart.curselection())))
    line_plot(df_covid_data, 'Area_Code', value)
    


listbox_Area_code_linechart = Listbox(Area_code)
listbox_Area_code_linechart.pack(side=LEFT, fill=BOTH, expand=True)

scrollbar = Scrollbar(Area_code)

scrollbar.pack(side=RIGHT, fill=BOTH)

for i in unique_AreaCode:
    listbox_Area_code_linechart.insert(END, i)

listbox_Area_code_linechart.config(yscrollcommand=scrollbar.set)
scrollbar.config(command=listbox_Area_code_linechart.yview)

listbox_Area_code_linechart.bind('<<ListboxSelect>>', code_linechart)

A1 = Button(Area_code, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')



def month_linechart(x):
    value = str((listbox_Months_linechart.get(listbox_Months_linechart.curselection())))
    if value != 0:
        line_plot(df_covid_data, 'Month', value)
        


listbox_Months_linechart = Listbox(Months)
listbox_Months_linechart.pack(side=LEFT, fill=BOTH, expand=True)
scrollbar_Months = Scrollbar(Months)

scrollbar_Months.pack(side=RIGHT, fill=BOTH)

for i in unique_Month:
    listbox_Months_linechart.insert(END, i)

listbox_Months_linechart.config(yscrollcommand=scrollbar_Months.set)
scrollbar_Months.config(command=listbox_Months_linechart.yview)

listbox_Months_linechart.bind('<<ListboxSelect>>', month_linechart)

A1 = Button(Months, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')



#===========================================================================================================
# defining functions for pie chart

def type_piechart(x):
    pie_plot(df_covid_data, 'Area_Type', str(x))
    

area_T_pie = StringVar(area_type_pie)
area_T_pie.set("Select")
v0_pie_chart = OptionMenu(area_type_pie, area_T_pie, *unique_Areatype, command=type_piechart)
v0_pie_chart.config(width=20, height=4)
v0_pie_chart.pack(padx=50, pady=50)


def code_piechart(x):
    value = str((listbox_Area_code.get(listbox_Area_code.curselection())))
    pie_plot(df_covid_data, 'Area_Code', value)
    


listbox_Area_code = Listbox(area_code_pie)
listbox_Area_code.pack(side=LEFT, fill=BOTH, expand=True)
scrollbar = Scrollbar(area_code_pie)

scrollbar.pack(side=RIGHT, fill=BOTH)

for i in unique_AreaCode:
    listbox_Area_code.insert(END, i)

listbox_Area_code.config(yscrollcommand=scrollbar.set)
scrollbar.config(command=listbox_Area_code.yview)

listbox_Area_code.bind('<<ListboxSelect>>', code_piechart)

A1 = Button(Area_code, text='Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.975, rely=0.95, relwidth=0.05, relheight=0.05, anchor='n')

A1 = Button(area_code_pie, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')


def name_piechart(x):
    if (listbox_Area_name.get(listbox_Area_name.curselection())) != "":
        value = str((listbox_Area_name.get(listbox_Area_name.curselection())))
        pie_plot(df_covid_data, 'Area_Name', value)
        


listbox_Area_name = Listbox(area_name_pie)
listbox_Area_name.pack(side=LEFT, fill=BOTH, expand=True)
scrollbar_Area_name = Scrollbar(area_name_pie)

scrollbar_Area_name.pack(side=RIGHT, fill=BOTH)

for i in unique_AreaName:
    listbox_Area_name.insert(END, i)

listbox_Area_name.config(yscrollcommand=scrollbar_Area_name.set)
scrollbar_Area_name.config(command=listbox_Area_name.yview)

listbox_Area_name.bind('<<ListboxSelect>>', name_piechart)

A1 = Button(area_name_pie, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')


def month_piechart(x):
    if (listbox_Months.get(listbox_Months.curselection())) != "":
        value = str((listbox_Months.get(listbox_Months.curselection())))
        pie_plot(df_covid_data, 'Month', value)
        


listbox_Months = Listbox(month_pie)
listbox_Months.pack(side=LEFT, fill=BOTH, expand=True)
scrollbar_Months = Scrollbar(month_pie)

scrollbar_Months.pack(side=RIGHT, fill=BOTH)

for i in unique_Month:
    listbox_Months.insert(END, i)

listbox_Months.config(yscrollcommand=scrollbar_Months.set)
scrollbar_Months.config(command=listbox_Months.yview)

listbox_Months.bind('<<ListboxSelect>>', month_piechart)

A1 = Button(month_pie, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')


# for boxplot 

def show_entry_fields():
    string = w2.get().split('&')
    string = set(string)
    boxplot_chart(df_covid_data, 'Area_Name', string)
    


def clear_entry(event):
    if str(w2.get()) != "":
        w2.delete(0, 'end')


def entre(x):
    ds = str(choice_list.get(choice_list.curselection()))
    w2.insert(0, ds + '&')

instruction = Label(boxplot, text="Please select the locations you want to visualize from the box below. \
\n \n(NOTE!!!! Please, do not type. Only Select as much as your screen can contain. To clear selection, click on text box)")
instruction.pack(fill='both', expand='True')
instruction.place(relx=0.5, rely=0.1, relwidth=0.75, relheight=0.1, anchor='n')

w2 = Entry(boxplot)
w2.pack(fill='both', expand="True")
w2.insert(0, "")
w2.place(relx=0.5, rely=0.2, relwidth=0.90, relheight=0.1, anchor='n')
w2.bind('<Button-1>', clear_entry)

r2 = Button(boxplot, text='Visualize', command=show_entry_fields)
r2.pack(fill='both', expand="True")
r2.place(relx=0.5, rely=0.3, relwidth=0.2, relheight=0.1, anchor='n')

choice_list = Listbox(boxplot)
choice_list.pack(fill=BOTH, expand=True)
choice_list.place(relx=0.5, rely=0.42, relwidth=0.6, relheight=0.47, anchor='n')

choice_list.bind('<<ListboxSelect>>', entre)

scrollbar = Scrollbar(boxplot)
scrollbar.pack(fill=BOTH)
scrollbar.place(relx=0.8, rely=0.42, relwidth=0.01, relheight=0.47, anchor='n')

for a in unique_AreaName:
    choice_list.insert(END, a)

choice_list.config(yscrollcommand=scrollbar.set)
scrollbar.config(command=choice_list.yview)








# for bar chart

def type_barchart(x):
    bar_chart(df_covid_data, 'Area_Type', str(x))
    

area_T_bar = StringVar(area_type_bar)
area_T_bar.set("Select")
v0_bar_chart = OptionMenu(area_type_bar, area_T_bar, *unique_Areatype, command=type_barchart)
v0_bar_chart.config(width=20, height=4)
v0_bar_chart.pack(padx=50, pady=50)


def code_barchart(x):
    value = str((listbox_Area_code1.get(listbox_Area_code1.curselection())))
    bar_chart(df_covid_data, 'Area_Code', value)
   

listbox_Area_code1 = Listbox(area_code_bar)
listbox_Area_code1.pack(side=LEFT, fill=BOTH, expand=True)
scrollbar = Scrollbar(area_code_bar)

scrollbar.pack(side=RIGHT, fill=BOTH)

for i in unique_AreaCode:
    listbox_Area_code1.insert(END, i)

listbox_Area_code1.config(yscrollcommand=scrollbar.set)
scrollbar.config(command=listbox_Area_code1.yview)

listbox_Area_code1.bind('<<ListboxSelect>>', code_barchart)


A1 = Button(area_code_bar, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')


def name_barchart(x):
    if (listbox_Area_name1.get(listbox_Area_name1.curselection())) != "":
        value = str((listbox_Area_name1.get(listbox_Area_name1.curselection())))
        bar_chart(df_covid_data, 'Area_Name', value)
       

listbox_Area_name1 = Listbox(area_name_bar)
listbox_Area_name1.pack(side=LEFT, fill=BOTH, expand=True)
scrollbar_Area_name1 = Scrollbar(area_name_bar)

scrollbar_Area_name1.pack(side=RIGHT, fill=BOTH)

for i in unique_AreaName:
    listbox_Area_name1.insert(END, i)

listbox_Area_name1.config(yscrollcommand=scrollbar_Area_name1.set)
scrollbar_Area_name1.config(command=listbox_Area_name1.yview)

listbox_Area_name1.bind('<<ListboxSelect>>', name_barchart)

A1 = Button(area_name_bar, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')


def month_barchart(x):
    if (listbox_Months1.get(listbox_Months1.curselection())) != "":
        value = str((listbox_Months1.get(listbox_Months1.curselection())))
        bar_chart(df_covid_data, 'Month', value)
        


listbox_Months1 = Listbox(month_bar)
listbox_Months1.pack(side=LEFT, fill=BOTH, expand=True)
scrollbar_Months1 = Scrollbar(month_bar)

scrollbar_Months1.pack(side=RIGHT, fill=BOTH)

for i in unique_Month:
    listbox_Months1.insert(END, i)

listbox_Months1.config(yscrollcommand=scrollbar_Months1.set)
scrollbar_Months1.config(command=listbox_Months1.yview)

listbox_Months1.bind('<<ListboxSelect>>', month_barchart)

A1 = Button(month_bar, text='My Home', bg='#ffb3fe', command=lambda: show_frame(Home_page))
A1.pack(fill='both', expand="True")
A1.place(relx=0.9, rely=0.9, relwidth=0.07, relheight=0.05, anchor='n')


########################################################################################################################
# for stop and search
SandS_label = Label(SandS, text="Please select the chart you want to use for visualization?")
SandS_label.pack(fill='both', expand='True')
SandS_label.place(relx=0.5, rely=0.1, relwidth=0.75, relheight=0.1, anchor='n')

SandS_button1 = Button(SandS, text="The Age \nDistribution", command=lambda: show_frame(SandS_hist))
SandS_button1.pack(fill='both', expand="True")
SandS_button1.place(relx=0.1, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

SandS_button2 = Button(SandS, text="Arrests vs. \nNon-Arrests", command=lambda: show_frame(arrests))
SandS_button2.pack(fill='both', expand="True")
SandS_button2.place(relx=0.3, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

SandS_button3 = Button(SandS, text="Comparison of Multiple\nAge Histogram", command=lambda: show_frame(m_SandS))
SandS_button3.pack(fill='both', expand="True")
SandS_button3.place(relx=0.5, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

SandS_button4 = Button(SandS, text="Gender \nDistribution", command=lambda: show_frame(gen_hist))
SandS_button4.pack(fill='both', expand="True")
SandS_button4.place(relx=0.7, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')

SandS_button5 = Button(SandS, text="Ethnic \nDistribution", command=lambda: show_frame(eth_hist))
SandS_button5.pack(fill='both', expand="True")
SandS_button5.place(relx=0.9, rely=0.4, relwidth=0.15, relheight=0.1, anchor='n')



# for Age Histogram

def show_e_fields():
    where = str(police_histogram.get())
    string = date.get().split('/')
    year = string[0]
    month = str(int(string[1]))

    print(where, year, month)
    hist_age_chart(where, year, month)


def clear_entry(event):
    if str(date.get()) != "":
        date.delete(0, 'end')


police_histogram = StringVar(SandS_hist)
police_histogram.set("Pick Police")
police_choice = OptionMenu(SandS_hist, police_histogram, *force_id)
police_choice.config(width=20, height=4)
police_choice.pack(padx=50, pady=50)
police_choice.place(relx=0.24, rely=0.1, relwidth=0.18, relheight=0.05, anchor='n')

information = Label(SandS_hist, text="Select police and enter the date you want to visualise\n \nIn the form 'YYYY/MM'")
information.pack(fill='both', expand='True')
information.place(relx=0.5, rely=0.01, relwidth=0.7, relheight=0.07, anchor='n')

date = Entry(SandS_hist)
date.pack(fill='both', expand="True")
date.insert(0, "2019/01")
date.place(relx=0.76, rely=0.1, relwidth=0.18, relheight=0.05, anchor='n')
date.bind('<Button-1>', clear_entry)

show_button = Button(SandS_hist, text='Visualize', command=show_e_fields)
show_button.pack(fill='both', expand="True")
show_button.place(relx=0.5, rely=0.3, relwidth=0.2, relheight=0.1, anchor='n')


# for the arrest vs non arrests chart

def just_go():
    wherein = str(result_police_histogram.get())
    string = datee.get().split('/')
    year = string[0]
    month = str(int(string[1]))
    result(wherein, year, month)


def clear_entry(event):
    if str(date.get()) != "":
        date.delete(0, 'end')


result_police_histogram = StringVar(arrests)
result_police_histogram.set("Select Police")
result_police_choice = OptionMenu(arrests, result_police_histogram, *force_id)
result_police_choice.config(width=20, height=4)
result_police_choice.pack(padx=50, pady=50)
result_police_choice.place(relx=0.24, rely=0.1, relwidth=0.18, relheight=0.05, anchor='n')

information = Label(arrests, text="Select police and enter the date you want to visualise\n \nIn the form 'YYYY/MM'")
information.pack(fill='both', expand='True')
information.place(relx=0.5, rely=0.01, relwidth=0.7, relheight=0.07, anchor='n')

datee = Entry(arrests)
datee.pack(fill='both', expand="True")
datee.insert(0, "2019/01")
datee.place(relx=0.76, rely=0.1, relwidth=0.18, relheight=0.05, anchor='n')
datee.bind('<Button-1>', clear_entry)

show_button = Button(arrests, text='Visualize', command=just_go)
show_button.pack(fill='both', expand="True")
show_button.place(relx=0.5, rely=0.3, relwidth=0.2, relheight=0.1, anchor='n')


# for multiple comparison

def work_out():
    whereat = police_input.get().replace(" ", "")
    whereat = whereat.split(',')
    whereat = set(whereat)

    string = during.get().split('/')
    year = string[0]
    month = str(int(string[1]))

    curious = []
    for n in whereat:
        if str(n) != '':
            each = [str(n), str(year), str(month)]
            curious.append(each)
    print(curious)
    compare_many(curious)


def clear_entry1(event):
    if str(police_input.get()) != "":
        police_input.delete(0, 'end')


def clear_entry2(event):
    during.delete(0, 'end')


def entrr(x):
    val = str((choice_listt.get(choice_listt.curselection())))
    police_input.insert(0, val + ',')


police_input = Entry(m_SandS)
police_input.pack(fill='both', expand="True")
police_input.insert(0, "")
police_input.place(relx=0.445, rely=0.1, relwidth=0.855, relheight=0.05, anchor='n')
police_input.bind('<Button-1>', clear_entry1)

info = Label(m_SandS, text="Select police and enter the date you want to visualise in the form 'YYYY/MM'\
 \n(Choose maximum of 6 or below for smooth experience)")
info.pack(fill='both', expand='True')
info.place(relx=0.5, rely=0.01, relwidth=0.96, relheight=0.07, anchor='n')

during = Entry(m_SandS)
during.pack(fill='both', expand="True")
during.insert(0, "2019/01")
during.place(relx=0.935, rely=0.1, relwidth=0.09, relheight=0.05, anchor='n')
during.bind('<Button-1>', clear_entry2)

show_button = Button(m_SandS, text='Visualize', command=work_out)
show_button.pack(fill='both', expand="True")
show_button.place(relx=0.5, rely=0.2, relwidth=0.1, relheight=0.05, anchor='n')

choice_listt = Listbox(m_SandS)
choice_listt.pack(fill=BOTH, expand=True)
choice_listt.place(relx=0.49, rely=0.3, relwidth=0.93, relheight=0.65, anchor='n')

choice_listt.bind('<<ListboxSelect>>', entrr)

scrollbar = Scrollbar(m_SandS)
scrollbar.pack(fill=BOTH)
scrollbar.place(relx=0.95, rely=0.3, relwidth=0.01, relheight=0.65, anchor='n')

for i in force_id:
    choice_listt.insert(END, i)

choice_listt.config(yscrollcommand=scrollbar.set)
scrollbar.config(command=choice_listt.yview)


# for gender distribution

def show_gen_fields():
    where = str(gen_police_histogram.get())
    string = date2.get().split('/')
    year = string[0]
    month = str(int(string[1]))

    print(where, year, month)
    hist_gender_chart(where, year, month)


def clear_entry3(event):
    if str(date2.get()) != "":
        date2.delete(0, 'end')


gen_police_histogram = StringVar(gen_hist)
gen_police_histogram.set("Pick Police")
gen_police_choice = OptionMenu(gen_hist, gen_police_histogram, *force_id)
gen_police_choice.config(width=20, height=4)
gen_police_choice.pack(padx=50, pady=50)
gen_police_choice.place(relx=0.24, rely=0.1, relwidth=0.18, relheight=0.05, anchor='n')

information2 = Label(gen_hist, text="Select police and enter the date you want to visualise\n \nIn the form 'YYYY/MM'")
information2.pack(fill='both', expand='True')
information2.place(relx=0.5, rely=0.01, relwidth=0.7, relheight=0.07, anchor='n')

date2 = Entry(gen_hist)
date2.pack(fill='both', expand="True")
date2.insert(0, "2019/01")
date2.place(relx=0.76, rely=0.1, relwidth=0.18, relheight=0.05, anchor='n')
date2.bind('<Button-1>', clear_entry3)

show_button = Button(gen_hist, text='Visualize', command=show_gen_fields)
show_button.pack(fill='both', expand="True")
show_button.place(relx=0.5, rely=0.3, relwidth=0.2, relheight=0.1, anchor='n')

# for ethnic distribution

def show_eth_fields():
    where = str(eth_police_histogram.get())
    string = date3.get().split('/')
    year = string[0]
    month = str(int(string[1]))

    print(where, year, month)
    hist_ethnic_chart(where, year, month)


def clear_entry4(event):
    if str(date3.get()) != "":
        date3.delete(0, 'end')


eth_police_histogram = StringVar(eth_hist)
eth_police_histogram.set("Pick Police")
eth_police_choice = OptionMenu(eth_hist, eth_police_histogram, *force_id)
eth_police_choice.config(width=20, height=4)
eth_police_choice.pack(padx=50, pady=50)
eth_police_choice.place(relx=0.24, rely=0.1, relwidth=0.18, relheight=0.05, anchor='n')

information3 = Label(eth_hist, text="Select police and enter the date you want to visualise\n \nIn the form 'YYYY/MM'")
information3.pack(fill='both', expand='True')
information3.place(relx=0.5, rely=0.01, relwidth=0.7, relheight=0.07, anchor='n')

date3 = Entry(eth_hist)
date3.pack(fill='both', expand="True")
date3.insert(0, "2019/01")
date3.place(relx=0.76, rely=0.1, relwidth=0.18, relheight=0.05, anchor='n')
date3.bind('<Button-1>', clear_entry4)

show_button = Button(eth_hist, text='Visualize', command=show_eth_fields)
show_button.pack(fill='both', expand="True")
show_button.place(relx=0.5, rely=0.3, relwidth=0.2, relheight=0.1, anchor='n')




show_frame(Home_page)
root.mainloop()
# Out:
# [['cheshire', '2019', '1'], ['dyfed-powys', '2019', '1'], ['derbyshire', '2019', '1']]
# ['cheshire', '2019', '1']
# ['dyfed-powys', '2019', '1']
# ['derbyshire', '2019', '1']
# ['cheshire', 'dyfed-powys', 'derbyshire']
#          cheshire  dyfed-powys  derbyshire
# 10-17          31           33          22
# 18-24          73           91          62
# 25-34          44           40          37
# over 34        47           26          27
